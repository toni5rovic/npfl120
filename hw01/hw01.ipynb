# %%
import pandas as pd
import numpy as np
from tqdm.auto import tqdm

# %%
df = pd.read_csv('data/language.tsv', sep='\t', na_filter=False)

# %%
df
# Out:
#      wals_code iso_code glottocode                   Name   latitude  \
# 0          aab                              Arapesh (Abu)  -3.450000
# 1          aar      aiw   aari1239                   Aari   6.000000
# 2          aba      aau   abau1245                   Abau  -4.000000
# 3          abb      shu   chad1249  Arabic (Abbéché Chad)  13.833333
# 4          abd      abi   abid1235                 Abidji   5.666667
# ...        ...      ...        ...                    ...        ...
# 2674       zte      zpz   texm1235   Zapotec (Texmelucan)  16.500000
# 2675       zul      zul   zulu1248                   Zulu -30.000000
# 2676       zun      zun   zuni1245                   Zuni  35.083333
# 2677       zya      zav   yatz1235     Zapotec (Yatzachi)  17.200000
# 2678       zzo      zpq   zoog1238     Zapotec (Zoogocho)  17.250000
#
#        longitude           genus        family      macroarea countrycodes  \
# 0     142.950000  Kombio-Arapesh    Torricelli                          PG
# 1      36.583333    South Omotic  Afro-Asiatic         Africa           ET
# 2     141.250000     Upper Sepik         Sepik      Papunesia           PG
# 3      20.833333         Semitic  Afro-Asiatic         Africa           TD
# 4      -4.583333             Kwa   Niger-Congo         Africa           CI
# ...          ...             ...           ...            ...          ...
# 2674  -97.166667       Zapotecan  Oto-Manguean  North America           MX
# 2675   30.000000         Bantoid   Niger-Congo         Africa           ZA
# 2676 -108.833333            Zuni          Zuni  North America           US
# 2677  -96.200000       Zapotecan  Oto-Manguean  North America           MX
# 2678  -96.250000       Zapotecan  Oto-Manguean  North America           MX
#
#       ...  137B M in Second Person Singular  136B M in First Person Singular  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...                               ...                              ...
# 2674  ...
# 2675  ...  1 No m in second person singular     2 m in first person singular
# 2676  ...  1 No m in second person singular  1 No m in first person singular
# 2677  ...
# 2678  ...
#
#      109B Other Roles of Applied Objects 10B Nasal Vowels in West Africa  \
# 0
# 1
# 2
# 3
# 4
# ...                                  ...                             ...
# 2674
# 2675                        1 Instrument
# 2676
# 2677
# 2678
#
#      25B Zero Marking of A and P Arguments  \
# 0
# 1
# 2
# 3
# 4
# ...                                    ...
# 2674
# 2675                    2 Non-zero marking
# 2676                    2 Non-zero marking
# 2677
# 2678
#
#      21B Exponence of Tense-Aspect-Mood Inflection  \
# 0
# 1
# 2
# 3
# 4
# ...                                            ...
# 2674
# 2675                         1 monoexponential TAM
# 2676
# 2677
# 2678
#
#      108B Productivity of the Antipassive Construction  \
# 0
# 1
# 2
# 3
# 4
# ...                                                ...
# 2674
# 2675                                  4 no antipassive
# 2676
# 2677
# 2678
#
#      130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 2674
# 2675
# 2676
# 2677
# 2678
#
#      58B Number of Possessive Nouns  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...
# 2674
# 2675                1 None reported
# 2676
# 2677
# 2678
#
#            79B Suppletion in Imperatives and Hortatives
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 2674
# 2675  5 None (= no suppletive imperatives reported i...
# 2676  5 None (= no suppletive imperatives reported i...
# 2677
# 2678
#
# [2679 rows x 202 columns]

# %%
df = df.replace("",np.NaN)

# %%
df[df['wals_code'] == 'nan']
# Out:
#      wals_code iso_code glottocode   Name  latitude  longitude    genus  \
# 1666       nan      kln   nand1266  Nandi      0.25       35.0  Nilotic
#
#                family macroarea countrycodes  ...  \
# 1666  Eastern Sudanic    Africa           KE  ...
#
#      137B M in Second Person Singular 136B M in First Person Singular  \
# 1666                              NaN                             NaN
#
#      109B Other Roles of Applied Objects 10B Nasal Vowels in West Africa  \
# 1666                                 NaN                             NaN
#
#      25B Zero Marking of A and P Arguments  \
# 1666                                   NaN
#
#      21B Exponence of Tense-Aspect-Mood Inflection  \
# 1666                         1 monoexponential TAM
#
#      108B Productivity of the Antipassive Construction  \
# 1666                                               NaN
#
#      130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 1666                                                NaN
#
#      58B Number of Possessive Nouns  \
# 1666                1 None reported
#
#      79B Suppletion in Imperatives and Hortatives
# 1666                                          NaN
#
# [1 rows x 202 columns]

# %% [markdown]
# # Task 1: Calculating similarity scores

# %%
def get_matching_features_number(df, language_X_code, language_Y_code, columns_to_ignore):
    features_matching = 0
    
    x_row = df.loc[df['wals_code'] == language_X_code].iloc[0]
    y_row = df.loc[df['wals_code'] == language_Y_code].iloc[0]
    
    for column in df.columns:            
        if column in columns_to_ignore:
            continue

        x_value = x_row[column]
        y_value = y_row[column]
        
        if pd.isnull(x_value):
            continue
        
        if pd.isnull(y_value):
            continue

        if x_value == y_value:
            features_matching += 1
    
    return features_matching, y_row

# %%
def calculate_similarities(df, chosen_language_code):
    columns_to_ignore = ['wals_code', 'iso_code', 
                         'glottocode', 'Name', 
                         'latitude', 'longitude', 
                         'countrycodes']
    total_number_of_features = len(df.columns) - len(columns_to_ignore)
    
    language_codes = df['wals_code']
    
    chosen_language_idx = df.index[df['wals_code'] == chosen_language_code]
    
    results = []
    
    for lang_code in tqdm(language_codes):
        # skipping the language itself
        if lang_code == chosen_language_code:
            continue
        
        matching_features, lang = get_matching_features_number(df, 
                                                               chosen_language_code, 
                                                               lang_code, 
                                                               columns_to_ignore)
        
        results.append({
            'wals_code': lang['wals_code'],
            'name': lang['Name'],
            'genus': lang['genus'],
            'family': lang['family'],
            'macroarea': lang['macroarea'],
            'matching_features': matching_features,
            'similarity_score': matching_features / total_number_of_features
        })
    
    df_results = pd.DataFrame(results)
    return df_results.sort_values('similarity_score', ascending=False)

# %%
results = calculate_similarities(df, "scr")
# Out:
#   0%|          | 0/2679 [00:00<?, ?it/s]

# %%
results.head(10)
# Out:
#      wals_code            name     genus         family macroarea  \
# 2038       rus         Russian    Slavic  Indo-European   Eurasia
# 783        grk  Greek (Modern)     Greek  Indo-European   Eurasia
# 1931       pol          Polish    Slavic  Indo-European   Eurasia
# 1321       lit      Lithuanian    Baltic  Indo-European   Eurasia
# 650        eng         English  Germanic  Indo-European   Eurasia
# 2123       slo         Slovene    Slavic  Indo-European   Eurasia
# 385        bul       Bulgarian    Slavic  Indo-European   Eurasia
# 2434       ukr       Ukrainian    Slavic  Indo-European   Eurasia
# 2154       spa         Spanish   Romance  Indo-European   Eurasia
# 543        cze           Czech    Slavic  Indo-European   Eurasia
#
#       matching_features  similarity_score
# 2038                 50          0.256410
# 783                  43          0.220513
# 1931                 43          0.220513
# 1321                 41          0.210256
# 650                  39          0.200000
# 2123                 38          0.194872
# 385                  38          0.194872
# 2434                 37          0.189744
# 2154                 37          0.189744
# 543                  36          0.184615

# %%
results.tail(10)
# Out:
#      wals_code               name                  genus        family  \
# 545        dab               Daba            Biu-Mandara  Afro-Asiatic
# 2316       tmp           Tampulma                    Gur   Niger-Congo
# 1873       pad              Padoe                Celebic  Austronesian
# 242        bfd            Biafada      Northern Atlantic   Niger-Congo
# 544        daa               Da'a                Celebic  Austronesian
# 1875       pag               Pagu       North Halmaheran   West Papuan
# 2311       tmk              Tumak            East Chadic  Afro-Asiatic
# 1877       pak            Pakanha  Northern Pama-Nyungan  Pama-Nyungan
# 538        cwe  Columbia-Wenatchi        Interior Salish      Salishan
# 1099       kkr           Kirikiri            Lakes Plain   Lakes Plain
#
#           macroarea  matching_features  similarity_score
# 545          Africa                  0               0.0
# 2316         Africa                  0               0.0
# 1873      Papunesia                  0               0.0
# 242          Africa                  0               0.0
# 544       Papunesia                  0               0.0
# 1875      Papunesia                  0               0.0
# 2311         Africa                  0               0.0
# 1877      Australia                  0               0.0
# 538   North America                  0               0.0
# 1099      Papunesia                  0               0.0

# %% [markdown]
# # Task 2: Finding centroid language for a given genus

# %%
def find_centroid_language(df, genus):
    columns_to_ignore = ['wals_code', 'iso_code', 
                         'glottocode', 'Name', 
                         'latitude', 'longitude', 
                         'countrycodes']
    total_number_of_features = len(df.columns) - len(columns_to_ignore)

    langs_in_genus = df.loc[df['genus'] == genus]['wals_code']

    matrix_of_similarities = np.zeros((len(langs_in_genus), len(langs_in_genus)))
    
    for i in range(len(langs_in_genus) - 1):
        for j in range(i+1, len(langs_in_genus)):
            i_code = langs_in_genus.iloc[i]
            j_code = langs_in_genus.iloc[j]
            
            fn, l = get_matching_features_number(df, i_code, j_code, columns_to_ignore)
            similarity = fn / total_number_of_features
            
            matrix_of_similarities[i, j] = similarity
            matrix_of_similarities[j, i] = similarity
    
    vector_total_similarities = matrix_of_similarities.sum(axis=0)
    idx_of_centroid_lang = np.argmax(vector_total_similarities)
    total_similarity_of_centroid = np.max(vector_total_similarities)
    
    return langs_in_genus.iloc[idx_of_centroid_lang], total_similarity_of_centroid

# %%
centroid_lang, max_similarity = find_centroid_language(df, 'Slavic')

# %%
centroid_lang, max_similarity
# Out:
# ('rus', 2.2256410256410257)

# %%
df[df['wals_code'] == centroid_lang]
# Out:
#      wals_code iso_code glottocode     Name  latitude  longitude   genus  \
# 2038       rus      rus   russ1263  Russian      56.0       38.0  Slavic
#
#              family macroarea countrycodes  ...  \
# 2038  Indo-European   Eurasia           RU  ...
#
#       137B M in Second Person Singular 136B M in First Person Singular  \
# 2038  1 No m in second person singular    2 m in first person singular
#
#      109B Other Roles of Applied Objects 10B Nasal Vowels in West Africa  \
# 2038       5 No applicative construction                             NaN
#
#      25B Zero Marking of A and P Arguments  \
# 2038                    2 Non-zero marking
#
#      21B Exponence of Tense-Aspect-Mood Inflection  \
# 2038                         1 monoexponential TAM
#
#      108B Productivity of the Antipassive Construction  \
# 2038                                  4 no antipassive
#
#      130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 2038                                                NaN
#
#      58B Number of Possessive Nouns  \
# 2038                1 None reported
#
#      79B Suppletion in Imperatives and Hortatives
# 2038                                 2 Imperative
#
# [1 rows x 202 columns]

# %%
centroid_lang, max_similarity = find_centroid_language(df, 'Romance')

# %%
centroid_lang, max_similarity
# Out:
# ('spa', 2.4358974358974352)

# %%
df[df['wals_code'] == centroid_lang]
# Out:
#      wals_code iso_code glottocode     Name  latitude  longitude    genus  \
# 2155       spa      spa   stan1288  Spanish      40.0       -4.0  Romance
#
#              family macroarea countrycodes  ...  \
# 2155  Indo-European   Eurasia           ES  ...
#
#       137B M in Second Person Singular 136B M in First Person Singular  \
# 2155  1 No m in second person singular    2 m in first person singular
#
#      109B Other Roles of Applied Objects 10B Nasal Vowels in West Africa  \
# 2155       5 No applicative construction                             NaN
#
#      25B Zero Marking of A and P Arguments  \
# 2155                    2 Non-zero marking
#
#      21B Exponence of Tense-Aspect-Mood Inflection  \
# 2155                               2 TAM+agreement
#
#      108B Productivity of the Antipassive Construction  \
# 2155                                  4 no antipassive
#
#      130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 2155                                                NaN
#
#      58B Number of Possessive Nouns  \
# 2155                1 None reported
#
#      79B Suppletion in Imperatives and Hortatives
# 2155                                 2 Imperative
#
# [1 rows x 202 columns]

# %%
centroid_lang, max_similarity = find_centroid_language(df, 'Semitic')

# %%
centroid_lang, max_similarity
# Out:
# ('aeg', 3.128205128205128)

# %%
df[df['wals_code'] == centroid_lang]
# Out:
#    wals_code iso_code glottocode               Name  latitude  longitude  \
# 34       aeg      arz   egyp1253  Arabic (Egyptian)      30.0       31.0
#
#       genus        family macroarea countrycodes  ...  \
# 34  Semitic  Afro-Asiatic    Africa           EG  ...
#
#     137B M in Second Person Singular  136B M in First Person Singular  \
# 34  1 No m in second person singular  1 No m in first person singular
#
#    109B Other Roles of Applied Objects 10B Nasal Vowels in West Africa  \
# 34       5 No applicative construction                             NaN
#
#    25B Zero Marking of A and P Arguments  \
# 34                    2 Non-zero marking
#
#    21B Exponence of Tense-Aspect-Mood Inflection  \
# 34                     3 TAM+agreement+diathesis
#
#    108B Productivity of the Antipassive Construction  \
# 34                                  4 no antipassive
#
#    130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 34                                                NaN
#
#    58B Number of Possessive Nouns 79B Suppletion in Imperatives and Hortatives
# 34                1 None reported                                 2 Imperative
#
# [1 rows x 202 columns]

# %% [markdown]
# # Task 3: Finding the "weirdest" language

# %%
def find_weirdest_language(df, genus=None, family=None):
    columns_to_ignore = ['wals_code', 'iso_code', 
                         'glottocode', 'Name', 
                         'latitude', 'longitude', 
                         'countrycodes']
    total_number_of_features = len(df.columns) - len(columns_to_ignore)

    langs = df
    if genus is not None:
        langs = langs[langs['genus'] == genus]
    if family is not None:
        langs = langs[langs['family'] == family]
    
    total_langs = len(langs)
    matrix_of_similarities = np.zeros((total_langs, total_langs))
    
    for i in tqdm(range(total_langs - 1)):
        for j in range(i+1, total_langs):
            i_code = langs.iloc[i]['wals_code']
            j_code = langs.iloc[j]['wals_code']
            
            fn, l = get_matching_features_number(langs, i_code, j_code, columns_to_ignore)
            similarity = fn / total_number_of_features
            
            matrix_of_similarities[i, j] = similarity
            matrix_of_similarities[j, i] = similarity
    
    vector_total_similarities = matrix_of_similarities.mean(axis=0)
    idx_of_weirdest_lang = np.argmin(vector_total_similarities)
    sim_of_weirdest_lang = np.min(vector_total_similarities)
    
    return langs.iloc[idx_of_weirdest_lang], sim_of_weirdest_lang

# %% [markdown]
# ### Family: Indo-European

# %%
weirdest_lang, weirdest_lang_sim = find_weirdest_language(df, family='Indo-European')
# Out:
#   0%|          | 0/175 [00:00<?, ?it/s]

# %%
weirdest_lang_sim
# Out:
# 0.007575757575757556

# %%
df[df['wals_code'] == weirdest_lang['wals_code']]
# Out:
#      wals_code iso_code glottocode                Name  latitude  longitude  \
# 2028       rse      NaN        NaN  Romani (Sepecides)     38.25       27.0
#
#       genus         family macroarea countrycodes  ...  \
# 2028  Indic  Indo-European       NaN           TR  ...
#
#      137B M in Second Person Singular 136B M in First Person Singular  \
# 2028                              NaN                             NaN
#
#      109B Other Roles of Applied Objects 10B Nasal Vowels in West Africa  \
# 2028                                 NaN                             NaN
#
#      25B Zero Marking of A and P Arguments  \
# 2028                                   NaN
#
#      21B Exponence of Tense-Aspect-Mood Inflection  \
# 2028                                           NaN
#
#      108B Productivity of the Antipassive Construction  \
# 2028                                               NaN
#
#      130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 2028                                                NaN
#
#      58B Number of Possessive Nouns  \
# 2028                            NaN
#
#      79B Suppletion in Imperatives and Hortatives
# 2028                                          NaN
#
# [1 rows x 202 columns]

# %% [markdown]
# ### Family: Dravidian

# %%
weirdest_lang, weirdest_lang_sim = find_weirdest_language(df, family='Dravidian')
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]

# %%
weirdest_lang_sim
# Out:
# 0.010702341137123744

# %%
df[df['wals_code'] == weirdest_lang['wals_code']]
# Out:
#     wals_code iso_code glottocode               Name  latitude  longitude  \
# 726       gdk      gdb   pott1240  Gadaba (Kondekor)     18.75       83.5
#
#                  genus     family macroarea countrycodes  ...  \
# 726  Central Dravidian  Dravidian   Eurasia           IN  ...
#
#     137B M in Second Person Singular 136B M in First Person Singular  \
# 726                              NaN                             NaN
#
#     109B Other Roles of Applied Objects 10B Nasal Vowels in West Africa  \
# 726                                 NaN                             NaN
#
#     25B Zero Marking of A and P Arguments  \
# 726                                   NaN
#
#     21B Exponence of Tense-Aspect-Mood Inflection  \
# 726                                           NaN
#
#     108B Productivity of the Antipassive Construction  \
# 726                                               NaN
#
#     130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 726                                                NaN
#
#     58B Number of Possessive Nouns  \
# 726                            NaN
#
#     79B Suppletion in Imperatives and Hortatives
# 726                                          NaN
#
# [1 rows x 202 columns]

# %% [markdown]
# ### Family: Niger-Congo

# %%
weirdest_lang, weirdest_lang_sim = find_weirdest_language(df, family='Niger-Congo')
# Out:
#   0%|          | 0/326 [00:00<?, ?it/s]

# %%
weirdest_lang_sim
# Out:
# 0.010381870932329618

# %%
df[df['wals_code'] == weirdest_lang['wals_code']]
# Out:
#      wals_code iso_code glottocode    Name  latitude  longitude  genus  \
# 2449       urh      urh   urho1239  Urhobo  5.583333        6.0  Edoid
#
#            family macroarea countrycodes  ...  \
# 2449  Niger-Congo    Africa           NG  ...
#
#      137B M in Second Person Singular 136B M in First Person Singular  \
# 2449                              NaN                             NaN
#
#      109B Other Roles of Applied Objects 10B Nasal Vowels in West Africa  \
# 2449                                 NaN                             NaN
#
#      25B Zero Marking of A and P Arguments  \
# 2449                                   NaN
#
#      21B Exponence of Tense-Aspect-Mood Inflection  \
# 2449                                           NaN
#
#      108B Productivity of the Antipassive Construction  \
# 2449                                               NaN
#
#      130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 2449                                                NaN
#
#      58B Number of Possessive Nouns  \
# 2449                            NaN
#
#      79B Suppletion in Imperatives and Hortatives
# 2449                                          NaN
#
# [1 rows x 202 columns]

# %% [markdown]
# ### Genus: Slavic

# %%
weirdest_lang, weirdest_lang_sim = find_weirdest_language(df, genus='Slavic')
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]

# %%
weirdest_lang_sim
# Out:
# 0.015082956259426846

# %%
df[df['wals_code'] == weirdest_lang['wals_code']]
# Out:
#     wals_code iso_code glottocode     Name  latitude  longitude   genus  \
# 329       bos      bos   bosn1245  Bosnian      43.0       18.0  Slavic
#
#             family macroarea countrycodes  ...  \
# 329  Indo-European   Eurasia           BA  ...
#
#     137B M in Second Person Singular 136B M in First Person Singular  \
# 329                              NaN                             NaN
#
#     109B Other Roles of Applied Objects 10B Nasal Vowels in West Africa  \
# 329                                 NaN                             NaN
#
#     25B Zero Marking of A and P Arguments  \
# 329                                   NaN
#
#     21B Exponence of Tense-Aspect-Mood Inflection  \
# 329                                           NaN
#
#     108B Productivity of the Antipassive Construction  \
# 329                                               NaN
#
#     130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 329                                                NaN
#
#     58B Number of Possessive Nouns  \
# 329                            NaN
#
#     79B Suppletion in Imperatives and Hortatives
# 329                                          NaN
#
# [1 rows x 202 columns]

# %% [markdown]
# ### Genus: Romance

# %%
weirdest_lang, weirdest_lang_sim = find_weirdest_language(df, genus='Romance')
# Out:
#   0%|          | 0/23 [00:00<?, ?it/s]

# %%
weirdest_lang_sim
# Out:
# 0.014957264957264958

# %%
df[df['wals_code'] == weirdest_lang['wals_code']]
# Out:
#      wals_code iso_code glottocode       Name  latitude  longitude    genus  \
# 1547       mol      ron   roma1327  Moldavian      47.0       29.0  Romance
#
#              family macroarea countrycodes  ...  \
# 1547  Indo-European   Eurasia           MD  ...
#
#      137B M in Second Person Singular 136B M in First Person Singular  \
# 1547                              NaN                             NaN
#
#      109B Other Roles of Applied Objects 10B Nasal Vowels in West Africa  \
# 1547                                 NaN                             NaN
#
#      25B Zero Marking of A and P Arguments  \
# 1547                                   NaN
#
#      21B Exponence of Tense-Aspect-Mood Inflection  \
# 1547                                           NaN
#
#      108B Productivity of the Antipassive Construction  \
# 1547                                               NaN
#
#      130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 1547                                                NaN
#
#      58B Number of Possessive Nouns  \
# 1547                            NaN
#
#      79B Suppletion in Imperatives and Hortatives
# 1547                                          NaN
#
# [1 rows x 202 columns]

# %% [markdown]
# ### Genus: Turkic

# %%
weirdest_lang, weirdest_lang_sim = find_weirdest_language(df, genus='Turkic')
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
weirdest_lang_sim
# Out:
# 0.01500938086303939

# %%
df[df['wals_code'] == weirdest_lang['wals_code']]
# Out:
#     wals_code iso_code glottocode    Name  latitude  longitude   genus  \
# 611       dol      dlg   dolg1241  Dolgan     71.25       98.0  Turkic
#
#      family macroarea countrycodes  ... 137B M in Second Person Singular  \
# 611  Altaic   Eurasia           RU  ...                              NaN
#
#     136B M in First Person Singular 109B Other Roles of Applied Objects  \
# 611                             NaN                                 NaN
#
#     10B Nasal Vowels in West Africa 25B Zero Marking of A and P Arguments  \
# 611                             NaN                                   NaN
#
#     21B Exponence of Tense-Aspect-Mood Inflection  \
# 611                                           NaN
#
#     108B Productivity of the Antipassive Construction  \
# 611                                               NaN
#
#     130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 611                                                NaN
#
#     58B Number of Possessive Nouns  \
# 611                            NaN
#
#     79B Suppletion in Imperatives and Hortatives
# 611                                          NaN
#
# [1 rows x 202 columns]
